# %%
#phosphours
def PIX():
    import cv2
    import numpy as np
    from PIL import Image
    def phosphours(event, x, y, flags, param):
            if event == cv2.EVENT_LBUTTONDBLCLK:
                r, g, b = rgbimg.getpixel((x,y))
                red = r * 100
                green = g * 10
                blue = b * 1
                thershold = red + green + blue
                if thershold <= 28030 and thershold > 27992: 
                    txt = str(thershold) + '''The Phosphours in the soil is "0"'''
                elif thershold <= 27992 and thershold > 27954:  
                    txt = str(thershold) + "The Phosphours is 10"
                elif thershold <= 27954 and thershold > 27827:   
                    txt = str(thershold) + "The Phosphours is 20"
                elif thershold <= 27827 and thershold > 27789:   
                    txt = str(thershold) + "The Phosphours is 40"
                elif thershold <= 27789 and thershold > 27751:   
                    txt = str(thershold) + "The Phosphours is 80"
                elif thershold <= 27751 and thershold > 27582:   
                    txt = str(thershold) + "The Phosphours is 90"
                elif thershold <= 27582 and thershold > 27403:  
                     txt = str(thershold) + "The Phosphours is 100"
                elif thershold <= 27403 and thershold > 27235:  
                    txt = str(thershold) + "The Phosphours is 110"
                elif thershold <= 27235 and thershold > 27056:   
                    txt = str(thershold) + "The Phosphours is 115"
                elif thershold <= 27056 and thershold > 26887:   
                    txt = str(thershold) + "The Phosphours is 120"
                elif thershold <= 26887 and thershold > 25126:   
                    txt = str(thershold) + "The Phosphours is 140"
                elif thershold <= 25126 and thershold > 23364:   
                    txt = str(thershold) + "The Phosphours is 160"
                elif thershold <= 23364 and thershold > 21613:  
                     txt = str(thershold) + "The Phosphours is 180"
                elif thershold <= 21613 and thershold > 19851:   
                    txt = str(thershold) + "The Phosphours is 200"
                elif thershold <= 19851 and thershold > 18090:   
                    txt = str(thershold) + "The Phosphours is 220"
                elif thershold == 18090:   
                    txt = str(thershold) + "The Phosphours is 240"


                else:
                    txt= "Not identified"
                bg = np.zeros((600, 600, 3), np.uint8)
                bg[:,0:400] = (b,g,r)
                font = cv2.FONT_ITALIC
                cv2.putText(bg, txt, (10,100), font, 1, (255,255,255), 2, cv2.LINE_AA)
                cv2.imshow('RGB Values',bg)
    cap = cv2.VideoCapture(0)
    while(True):
        ret, frame = cap.read()
        flipped = cv2.flip(frame, 1)
        cv2.imshow('vid', flipped)
        if cv2.waitKey(1) & 0xFF == ord('c'): #press 'c' to capture the 
            cv2.imwrite('1.png',flipped)
            imge = Image.open('1.png')
            rgbimg = imge.convert('RGB')
            cv2.imshow('Select Area for RGB Values',flipped)
            cv2.setMouseCallback('Select Area for RGB Values', phosphours) #function that captures the current pixel and displays on a window

        elif cv2.waitKey(1) & 0xFF == ord('q'): 
            break
    cap.release()
    cv2.destroyAllWindows()

PIX()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\Android_Work\practice\soiltesting\Documentation\Soil_Nutrients_Detection .ipynb Cell 1' in <cell line: 71>()
#      <a href='vscode-notebook-cell:/d%3A/Android_Work/practice/soiltesting/Documentation/Soil_Nutrients_Detection%20.ipynb#ch0000000?line=67'>68</a>     cap.release()
#      <a href='vscode-notebook-cell:/d%3A/Android_Work/practice/soiltesting/Documentation/Soil_Nutrients_Detection%20.ipynb#ch0000000?line=68'>69</a>     cv2.destroyAllWindows()
# ---> <a href='vscode-notebook-cell:/d%3A/Android_Work/practice/soiltesting/Documentation/Soil_Nutrients_Detection%20.ipynb#ch0000000?line=70'>71</a> PIX()
#
# d:\Android_Work\practice\soiltesting\Documentation\Soil_Nutrients_Detection .ipynb Cell 1' in PIX()
# ...

# %%
#potassium
def PIX():
    import cv2
    import numpy as np
    from PIL import Image
    def potassium (event, x, y, flags, param):
        if event == cv2.EVENT_LBUTTONDBLCLK:
            r, g, b = rgbimg.getpixel((x,y))
            red = r * 100
            green = g * 10
            blue = b * 1
            thershold = red + green + blue
            if thershold <= 27675 and thershold > 26962: 
                txt = str(thershold) + '''The potassium in the soil is "0"'''
            elif thershold <= 26962 and thershold > 26250:  
                txt = str(thershold) + "The potassium is 10"
            elif thershold <= 26250 and thershold > 25427:   
                txt = str(thershold) + "The potassium is 20"
            elif thershold <= 25427 and thershold > 24715:   
                txt = str(thershold) + "The potassium is 40"
            elif thershold <= 24715 and thershold > 24002:   
                txt = str(thershold) + "The potassium is 80"
            elif thershold <= 24002 and thershold > 23492:   
                txt = str(thershold) + "The potassium is 90"
            elif thershold <= 23492 and thershold > 23072:  
                 txt = str(thershold) + "The potassium is 100"
            elif thershold <= 23072 and thershold > 22562:  
                txt = str(thershold) + "The potassium is 110"
            elif thershold <= 22562 and thershold > 22142:   
                txt = str(thershold) + "The potassium is 115"
            elif thershold <= 22142 and thershold > 21632:   
                txt = str(thershold) + "The potassium is 120"
            elif thershold <= 21632 and thershold > 20591:   
                txt = str(thershold) + "The potassium is 140"
            elif thershold <= 20591 and thershold > 19541:   
                txt = str(thershold) + "The potassium is 160"
            elif thershold <= 19541 and thershold > 18600:  
                 txt = str(thershold) + "The potassium is 180"
            elif thershold <= 18600 and thershold > 17550:   
                txt = str(thershold) + "The potassium is 200"
            elif thershold <= 17550 and thershold > 16509:   
                txt = str(thershold) + "The potassium is 220"
            elif thershold == 16509:   
                txt = str(thershold) + "The potassium is 240"
            else:
                txt= "Not identified"
            bg = np.zeros((600, 600, 3), np.uint8)
            bg[:,0:400] = (b,g,r)
            font = cv2.FONT_ITALIC
            cv2.putText(bg, txt, (10,100), font, 1, (255,255,255), 2, cv2.LINE_AA)
            cv2.imshow('RGB Values',bg)
    cap = cv2.VideoCapture(0)
    while(True):
        ret, frame = cap.read()
        flipped = cv2.flip(frame, 1)
        cv2.imshow('vid', flipped)
        if cv2.waitKey(1) & 0xFF == ord('c'): #press 'c' to capture the 
            cv2.imwrite('1.png',flipped)
            imge = Image.open('1.png')
            rgbimg = imge.convert('RGB')
            cv2.imshow('Select Area for RGB Values',flipped)
            cv2.setMouseCallback('Select Area for RGB Values', potassium) #function that captures the current pixel and displays on a window

        elif cv2.waitKey(1) & 0xFF == ord('q'): 
            break
    cap.release()
    cv2.destroyAllWindows()

PIX()

# %%
#ph
def PIX():
    import cv2
    import numpy as np
    from PIL import Image
    def ph(event, x, y, flags, param):
        if event == cv2.EVENT_LBUTTONDBLCLK:
            r, g, b = rgbimg.getpixel((x,y))
            red = r * 100
            green = g * 10
            blue = b * 1
            thershold = red + green + blue
            if thershold >= 24018 and thershold < 24250:
                txt = str(thershold) + "The PH is 4.0"
            elif thershold >= 24605 and thershold < 24664:
                txt = str(thershold) + "The PH is 4.4"
            elif thershold >= 24960 and thershold < 24996:
                txt = str(thershold) + "The PH is 4.8"
            elif thershold >= 25022 and thershold < 25158:
                txt = str(thershold) + "The PH is 5"
            elif thershold >= 25184 and thershold < 25613:
                txt = str(thershold) + "The PH is "
            elif thershold >= 25914 and thershold < 26106:
                txt = str(thershold) + "The PH is 5.4"
            elif thershold > 25897 and thershold <= 26307 :
                txt = str(thershold) + "The PH is 5.8"
            elif thershold > 24445 and thershold <= 24966:
                txt = str(thershold) + "The PH is 6"
            elif thershold >  21698 and thershold <= 22816 :
                txt = str(thershold) + "The PH is 6.4"
            elif thershold > 19361 and thershold <= 20479:
                txt = str(thershold) + "The PH is 7"
            elif thershold >= 3933 and thershold < 8529:
                txt = str(thershold) + "The PH is 9"
            elif thershold < 18142 and thershold >= 10872:
                txt = str(thershold) + "The PH is 10"
               
            else:
                txt= "Not identified"
            bg = np.zeros((600, 600, 3), np.uint8)
            bg[:,0:400] = (b,g,r)
            font = cv2.FONT_ITALIC
            cv2.putText(bg, txt, (10,100), font, 1, (255,255,255), 2, cv2.LINE_AA)
            cv2.imshow('RGB Values',bg)
    cap = cv2.VideoCapture(0)
    while(True):
        ret, frame = cap.read()
        flipped = cv2.flip(frame, 1)
        cv2.imshow('vid', flipped)
        if cv2.waitKey(1) & 0xFF == ord('c'): #press 'c' to capture the 
            cv2.imwrite('1.png',flipped)
            imge = Image.open('1.png')
            rgbimg = imge.convert('RGB')
            cv2.imshow('Select Area for RGB Values',flipped)
            cv2.setMouseCallback('Select Area for RGB Values', potassium) #function that captures the current pixel and displays on a window

        elif cv2.waitKey(1) & 0xFF == ord('q'): 
            break
    cap.release()
    cv2.destroyAllWindows()

PIX()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\Android_Work\practice\soiltesting\Documentation\Soil_Nutrients_Detection .ipynb Cell 2' in <cell line: 62>()
#      <a href='vscode-notebook-cell:/d%3A/Android_Work/practice/soiltesting/Documentation/Soil_Nutrients_Detection%20.ipynb#ch0000001?line=58'>59</a>     cap.release()
#      <a href='vscode-notebook-cell:/d%3A/Android_Work/practice/soiltesting/Documentation/Soil_Nutrients_Detection%20.ipynb#ch0000001?line=59'>60</a>     cv2.destroyAllWindows()
# ---> <a href='vscode-notebook-cell:/d%3A/Android_Work/practice/soiltesting/Documentation/Soil_Nutrients_Detection%20.ipynb#ch0000001?line=61'>62</a> PIX()
#
# d:\Android_Work\practice\soiltesting\Documentation\Soil_Nutrients_Detection .ipynb Cell 2' in PIX()
# ...

# %%
#phosphours
def PIX():
    import cv2
    import numpy as np
    from PIL import Image
    def phosphours(event, x, y, flags, param):
            if event == cv2.EVENT_LBUTTONDBLCLK:
                r, g, b = rgbimg.getpixel((x,y))
                red = r * 100
                green = g * 10
                blue = b * 1
                thershold = red + green + blue
                if thershold <= 28030 and thershold > 27992: 
                    txt = str(thershold) + '''The Phosphours in the soil is "0"'''
                elif thershold <= 27992 and thershold > 27954:  
                    txt = str(thershold) + "The Phosphours is 10"
                elif thershold <= 27954 and thershold > 27827:   
                    txt = str(thershold) + "The Phosphours is 20"
                elif thershold <= 27827 and thershold > 27789:   
                    txt = str(thershold) + "The Phosphours is 40"
                elif thershold <= 27789 and thershold > 27751:   
                    txt = str(thershold) + "The Phosphours is 80"
                elif thershold <= 27751 and thershold > 27582:   
                    txt = str(thershold) + "The Phosphours is 90"
                elif thershold <= 27582 and thershold > 27403:  
                     txt = str(thershold) + "The Phosphours is 100"
                elif thershold <= 27403 and thershold > 27235:  
                    txt = str(thershold) + "The Phosphours is 110"
                elif thershold <= 27235 and thershold > 27056:   
                    txt = str(thershold) + "The Phosphours is 115"
                elif thershold <= 27056 and thershold > 26887:   
                    txt = str(thershold) + "The Phosphours is 120"
                elif thershold <= 26887 and thershold > 25126:   
                    txt = str(thershold) + "The Phosphours is 140"
                elif thershold <= 25126 and thershold > 23364:   
                    txt = str(thershold) + "The Phosphours is 160"
                elif thershold <= 23364 and thershold > 21613:  
                     txt = str(thershold) + "The Phosphours is 180"
                elif thershold <= 21613 and thershold > 19851:   
                    txt = str(thershold) + "The Phosphours is 200"
                elif thershold <= 19851 and thershold > 18090:   
                    txt = str(thershold) + "The Phosphours is 220"
                elif thershold == 18090:   
                    txt = str(thershold) + "The Phosphours is 240"


                else:
                    txt= "Not identified"
                bg = np.zeros((600, 600, 3), np.uint8)
                bg[:,0:400] = (b,g,r)
                font = cv2.FONT_ITALIC
                cv2.putText(bg, txt, (10,100), font, 1, (255,255,255), 2, cv2.LINE_AA)
                cv2.imshow('RGB Values',bg)
    cap = cv2.VideoCapture(0)
    while(True):
        ret, frame = cap.read()
        flipped = cv2.flip(frame, 1)
        cv2.imshow('vid', flipped)
        if cv2.waitKey(1) & 0xFF == ord('c'): #press 'c' to capture the 
            cv2.imwrite('1.png',flipped)
            imge = Image.open('1.png')
            rgbimg = imge.convert('RGB')
            cv2.imshow('Select Area for RGB Values',flipped)
            cv2.setMouseCallback('Select Area for RGB Values', phosphours) #function that captures the current pixel and displays on a window

        elif cv2.waitKey(1) & 0xFF == ord('q'): 
            break
    cap.release()
    cv2.destroyAllWindows()

PIX()
